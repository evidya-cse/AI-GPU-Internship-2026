# %%
from google import genai

client = genai.Client(
    api_key="AQ.Ab8RN6LcQzj3byrypxVVs9XAcNyRQHlNi8E5Vr7OxXcXGEh6fw"
)

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="Classify sentiment: The laptop is amazing. Output only Positive, Negative, or Neutral."
)

print(response.text)
# Out:
# Positive

# %%
from google import genai
API_KEY = "AQ.Ab8RN6LcQzj3byrypxVVs9XAcNyRQHlNi8E5Vr7OxXcXGEh6fw"
client = genai.Client(api_key=API_KEY)

prompt = """
Classify sentiment.

Example 1:
Review: The product is amazing.
Sentiment: Positive

Example 2:
Review: The service was terrible.
Sentiment: Negative

Example 3:
Review: The experience was okay.
Sentiment: Neutral

Now classify:

Review: The laptop performance is excellent and battery life is amazing.

Sentiment:
"""

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=prompt
)

print(response.text)
# Out:
# Sentiment: Positive

# %%
from groq import Groq

client = Groq(
    api_key="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"
)

prompt = """
A company has 125 employees.

40% work in Software Development.
25% work in Testing.
The remaining employees work in Support.

Think step by step and calculate:

1. Number of Software Developers
2. Number of Test Engineers
3. Number of Support Staff
"""

response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {"role": "user", "content": prompt}
    ]
)

print(response.choices[0].message.content)
# Out:
# To calculate the number of employees in each department, we need to find the percentage of employees in each department and multiply it by the total number of employees.
#
# 1. Number of Software Developers:
# 40% of 125 employees = 0.4 * 125 = 50
#
# 2. Number of Test Engineers:
# 25% of 125 employees = 0.25 * 125 = 31.25
#
# Since we can't have a fraction of an employee, we round down to the nearest whole number (as you can't have a quarter of a person). However, in this context, it's more accurate to understand that 31.25 represents the exact percentage of employees, and it might be split in some way within the company (like job sharing), but for counting whole individuals, we consider 31 employees as the test engineers.
#
# 3. Number of Support Staff:
# First, calculate the percentage of employees in Software Development and Testing combined:
# 40% (Software Development) + 25% (Testing) = 65%
#
# Then, subtract this combined percentage from 100% to find the percentage of employees in Support:
# 100% - 65% = 35%
#
# Now, calculate the number of Support Staff:
# 35% of 125 employees = 0.35 * 125 = 43.75
#
# Again, we deal with the fractional part by understanding it represents the proportion of employees, but for individual counting, we acknowledge 43.75 as the support staff number. However, since we must provide a whole number and considering that all fractional parts should be addressed in context, let's properly account for all employees:
#
# - Software Developers: 50
# - Test Engineers: 31
# - Total accounted so far: 50 + 31 = 81
#
# To find the number of Support Staff without dealing with fractions:
# Total employees = 125
# Employees in Support = Total employees - (Software Developers + Test Engineers)
# = 125 - 81
# = 44
#
# Thus, there are 50 Software Developers, 31 Test Engineers, and 44 Support Staff. This accounts for all 125 employees without splitting individuals, providing a more practical distribution for the company's workforce.

# %%
from groq import Groq

client = Groq(
    api_key="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"
)

prompt = """
### INSTRUCTION ###

Summarize the text in exactly 3 bullet points.

### INPUT TEXT ###

Artificial Intelligence is transforming
education by enabling personalized learning,
automated assessment systems, intelligent
tutoring platforms, and content generation.
It helps students learn at their own pace
while reducing administrative burden on
educators.

### OUTPUT ###
"""

response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {"role": "user", "content": prompt}
    ]
)

print(response.choices[0].message.content)
# Out:
# * Artificial Intelligence is transforming education by enabling various advanced technologies.
# * These technologies include personalized learning, automated assessment systems, intelligent tutoring platforms, and content generation.
# * The implementation of AI in education helps students learn at their own pace and reduces the administrative burden on educators.
